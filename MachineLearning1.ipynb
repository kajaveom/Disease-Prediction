# %%
#importing packages

import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data=pd.read_csv('/content/drive/MyDrive/Analytics J Component/encoded.csv') #reading the encoded data file
data1=pd.read_csv('/content/drive/MyDrive/Analytics J Component/UniqueD.csv')   #reading the original file

# %%
print(data.head(n=5)) #printing the first 5 rows of the emcoded data set.
# Out:
#    Unnamed: 0  X  Disease  Symptom_1  Symptom_2  Symptom_3
# 0           1  1       16         34         36         36
# 1           2  2       16         25         28         19
# 2           3  3       16         34         28         19
# 3           4  4       16         34         36         19
# 4           5  5       16         34         36         36

# %%
data=data.drop(['X'],axis=1) #dropping the not required column 'X'

# %%
data=data.drop(['Unnamed: 0'],axis=1) #dropping the not required column 'Unnamed: 0'

# %%
print(data.head(n=5))  #printing the first fivee records of data after dropping the columns.
# Out:
#    Disease  Symptom_1  Symptom_2  Symptom_3
# 0       16         34         36         36
# 1       16         25         28         19
# 2       16         34         28         19
# 3       16         34         36         19
# 4       16         34         36         36

# %%
features=data.iloc[:,1:4] #extracitng the feature set
print(features)
target=data['Disease'] #extracting the target value
print(target)
# Out:
#       Symptom_1  Symptom_2  Symptom_3
# 0            34         36         36
# 1            25         28         19
# 2            34         28         19
# 3            34         36         19
# 4            34         36         36
# ...         ...        ...        ...
# 4915         29         18         34
# 4916         25         32          4
# 4917          5          5         23
# 4918         25         21         43
# 4919         25         19          5
#
# [4920 rows x 3 columns]
# 0       16
# 1       16
# 2       16
# 3       16
# 4       16
#         ..
# 4915     1
# 4916     2
# 4917    40
# 4918    37
# 4919    29
# Name: Disease, Length: 4920, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import accuracy_score

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.20)

# %%
classifier =DecisionTreeClassifier()     # create a classifier object
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = classifier.predict(X_test)  #predicting the target value for testing data

# %%
data_p=pd.DataFrame({'Actual':y_test, 'Predicted':y_pred})   #visualing the actaul and predicted value
data_p
# Out:
#       Actual  Predicted
# 2107      35         35
# 3866       8          8
# 4627       6          6
# 825       16         16
# 829       16         16
# ...      ...        ...
# 3222       4          4
# 15         5          5
# 653        4          4
# 1941      41         41
# 3961      38         39
#
# [984 rows x 2 columns]

# %%
#testing the predicted value for a record.
test=[[34,36,36]]
test = pd.DataFrame(test,columns=['Symptom_1','Symptom_2','Symptom_3'])
print(test)
predicted=classifier.predict(test)
num=predicted[0]

df2=data1.loc[data1['encodedV'] == num, 'Diseases']
print("The predicted diseases based on the symptoms is: ",df2[0])
# Out:
#    Symptom_1  Symptom_2  Symptom_3
# 0         34         36         36
# The predicted diseases based on the symptoms is:  Fungal infection

# %%
import math
print("Accuracy:",round(metrics.accuracy_score(y_test, y_pred),4)*100,"%") #printing the accuracy of the model
# Out:
# Accuracy: 94.41000000000001 %

# %%
from sklearn.tree import export_graphviz  #visualisng the decision tree.
from six import StringIO
from IPython.display import Image
import pydotplus
name=['16', '5', '18', '10', '15', '35', '3', '13', '17', '7', '25', '32', '8', '34', '30', '31' ,'9', '12', '39', '20', '21', '22', '23','24', '4', '38', '11', '36', '14', '19', '41', '28' ,'26' ,'27' ,'33', '6', '1', '2', '40', '37', '29']
value=['Symptom_1','Symptom_2','Symptom_3']
dot_data = StringIO()
export_graphviz(classifier,out_file=dot_data,filled=True,rounded=True,special_characters=True,feature_names =value,class_names=name)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
graph.write_png('tree.png')
Image(graph.create_png())
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
metrics.classification_report(y_test,y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n           1       1.00      1.00      1.00        26\n           2       1.00      1.00      1.00        23\n           3       1.00      1.00      1.00        20\n           4       1.00      1.00      1.00        21\n           5       1.00      1.00      1.00        27\n           6       1.00      1.00      1.00        24\n           7       1.00      1.00      1.00        20\n           8       1.00      1.00      1.00        27\n           9       1.00      1.00      1.00        22\n          10       1.00      1.00      1.00        29\n          11       1.00      0.96      0.98        24\n          12       1.00      1.00      1.00        34\n          13       0.96      1.00      0.98        25\n          14       1.00      1.00      1.00        28\n          15       1.00      1.00      1.00        21\n          16       1.00      1.00      1.00        16\n          17       1.00      1.00      1.00        21\n     
# ...

# %%
from sklearn.metrics import f1_score, precision_score,recall_score
print("F1 Score : ",f1_score(y_test, y_pred, 
                                           pos_label='positive', average='micro'))
print("Precision Score : ",precision_score(y_test, y_pred,  pos_label='positive',average='micro'))
print("Recall Score : ",recall_score(y_test, y_pred, 
                                           pos_label='positive', average='micro'))
# Out:
# F1 Score :  0.9441056910569106
# Precision Score :  0.9441056910569106
# Recall Score :  0.9441056910569106
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1375: UserWarning: Note that pos_label (set to 'positive') is ignored when average != 'binary' (got 'micro'). You may use labels=[pos_label] to specify a single positive class.
#   UserWarning,

# %%
from sklearn.tree import export_graphviz  #visualisng the decision tree.
from six import StringIO
from IPython.display import Image
import pydotplus
name=['10', '23', '31', '13', '25', '5', '3', '33', '14', '35', '25', '32', '21', '24', '30', '31' ,'9', '12', '39', '20', '21', '22', '23','24', '4', '38', '11', '36', '14', '19', '41', '28' ,'26' ,'27' ,'33', '6', '1', '2', '40', '37', '29']
value=['Symptom_1','Symptom_2','Symptom_3']
dot_data = StringIO()
export_graphviz(classifier,out_file=dot_data,filled=True,rounded=True,special_characters=True,feature_names =value,class_names=name)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
graph.write_png('tree.png')
Image(graph.create_png())
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
#testing the predicted value for a record.
test=[[10,23,31]]
test = pd.DataFrame(test,columns=['Symptom_1','Symptom_2','Symptom_3'])
print(test)
predicted=classifier.predict(test)
num=predicted[0]

df2=data1.loc[data1['encodedV'] == num, 'Diseases']
print(df2)
print("The predicted diseases based on the symptoms is: ",df2)
# Out:
#    Symptom_1  Symptom_2  Symptom_3
# 0         10         23         31
# 20    Hepatitis B
# Name: Diseases, dtype: object
# The predicted diseases based on the symptoms is:  20    Hepatitis B
# Name: Diseases, dtype: object

# %%
#testing the predicted value for a record.
test=[[10,23,31]]
test = pd.DataFrame(test,columns=['Symptom_1','Symptom_2','Symptom_3'])
print(test)
predicted=classifier.predict(test)
num=predicted[0]

df2=data1.loc[data1['encodedV'] == num, 'Diseases']
print(df2)
print("The predicted diseases based on the symptoms is: ",df2)

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test,y_pred)
print(mse)
# Out:
# 0.9491869918699187

# %%
import math
rmse=math.sqrt(mse)
rmse
# Out:
# 0.974262280841211
